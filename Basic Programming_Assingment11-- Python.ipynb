# %% [markdown]
# 1. Write a Python program to find words which are greater than given length k?
# Ans:
# k=10
#
# words=input()
#
# if len(words)>k:
#     print('Greater')
# else:
#     print('lesser than K')
#
#
# 2. Write a Python program for removing i-th character from a string?
# Ans:
# i=int(input())
#
# Str="Rahul Wants To be a Data Analyst"
#
#
# LStr=list(Str)
#
# LStr.pop(i)
#
# 3. Write a Python program to split and join a string?
# Ans:Str="Rahul,Wants, To, be, a, Data, Analyst"
# a=Str.split(',')
# "-".join(a)
#
#
#
# 4. Write a Python to check if a given string is binary string or not?
# Ans:
# stringA = '0110101010111'
# b = {'0','1'}
# t = set(stringA)
#
# if b == t or t == {'0'} or t == {'1'}:
#    print("StringA is a binary string.")
# else:
#    print("StringA is not a binary string.")
#
# stringB = '0120101010111'
# u = set(stringB)
#
# if b == u or u == {'0'} or u == {'1'}:
#    print("StringB is a binary string.")
# else:
#    print("StringB is not a binary string.")
#
# 5. Write a Python program to find uncommon words from two Strings?
# Ans:
# str1='good idea'
# str2= 'bad idea'
#
# a1=str1.split()
# a2=str2.split()
#
# def uncommon_words(a,b):
#     uc_words=""
#     for i in a1:
#         if i not in a2:
#             uc_words=uc_words+i
#
#     for j in a2:
#         if j not in a1:
#             uc_words=uc_words+j
#     return uc_words
#
#
#
#
# 6. Write a Python to find all duplicate characters in string?
# Ans:str1='good idea'
# str2= 'bad idea'
# a1=str1.split()
# a2=str2.split()
#
#
#
# def common_words1(a,b):
#     c_words=""
#     for i in a1:
#         if i in a2:
#             c_words=c_words+i
#
#     for j in a2:
#         if j  in a1:
#             c_words=c_words+j
#     return c_words
#
#
#
# 7. Write a Python Program to check if a string contains any special character?
# Ans:import re
# def find(string):
#     special_char=re.compile('[@_!$%^&*()<>?/\|}{~:#]')
#
#     if special_char.search(string)==None:
#         return('String Is accepted')
#
#     else:
#         return('String Is not Accepted')
#
#
# Str5='Rahul #'
# print(Str5)
# print(find(Str5))
