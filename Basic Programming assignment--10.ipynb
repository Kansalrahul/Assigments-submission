# %% [markdown]
# 1.Write a Python program to find sum of elements in list?
# Ans:l=[1,2,3,4,5,6]
# def sumlist(l):
#     sum=0
#     for i in range(len(l)):
#         sum=sum+l[i]
#     return sum
#
# print('sum of numbers are',sumlist(l))
#
#
# 2.Write a Python program to  Multiply all numbers in the list?
# Ans:l=[1,2,3,4,5,6]
# def sumlist(l):
#     sum=1
#     for i in range(len(l)):
#         sum=sum*l[i]
#     return sum
#
# print('sum of numbers are',sumlist(l))
#
#
# 3.Write a Python program to find smallest number in a list?
# Ans:l=[1,2,3,4,5,6]
# min(l)
#
#
# 4.Write a Python program to find largest number in a list?
# Ans:l=[1,2,3,4,5,6]
# max(l)
#
#
# 5.Write a Python program to find second largest number in a list?
# Ans:list1=[1,25,36,1,25,25,36,1,26]
# list1.sort()
#
# a=set(list1)
# list1.remove(max(a))
# max(list1)
#
#
# 6.Write a Python program to find N largest elements from a list?
# Ans:def N_max_elements(list, N):
#     result_list = []
#
#     for i in range(0, N):
#         maximum = 0
#
#         for j in range(len(list)):
#             if list[j] > maximum:
#                 maximum = list[j]
#
#         list.remove(maximum)
#         result_list.append(maximum)
#
#     return result_list
#
# print(N_max_elements(list2,4))
#
#
# 7.Write a Python program to print even numbers in a list?
# Ans:for i in l:
#     if i%2==0:
#         print('these are even numbers')
#         print(i)
#
# 8.Write a Python program to print odd numbers in a List?
# Ans:for i in l:
#     if i%2!=0:
#         print('these are odd numbers')
#         print(i)
#
# 9.Write a Python program to Remove empty List from List?
# Ans:list1=[[],[],[],23,25,36,[],253,[]]
# print(list1)
# list2=[x for x in list1 if x]
# print(list2)
#
# 10.Write a Python program to Cloning or Copying a list?
# Ans:Original_list=[25,36,14,19,36]
#
# new_list=Original_list
#
# print(Original_list)
# print(new_list)
#
# 11.Write a Python program to Count occurrences of an element in a list?
# Ans:list1=[1,25,36,1,25,25,36,1,26]
# def occurence_list(list,n):
#     count=0
#     for i in list:
#         if n==i:
#             count=count+1
#     return count
#
# x=int(input('enter element to be count'))
# print(x,"has occured",occurence_list(list1,1),"times")
