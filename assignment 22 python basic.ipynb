# %% [markdown]
# 1. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# print(X)
#
#
# >>> func()
# Ans:iNeuron
# because x= ineuron we have create a function which prints the value of x.
#
# 2. What is the result of the code, and explain?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI!'
#
#
# >>> func()
# >>> print(X)
# Ans:iNeuron
# beacuse both are outside the function they are global variable.
#
#
#
# 3. What does this code print, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# print(X)
#
#
# >>> func()
# >>> print(X)
# Ams:NI
# iNeuron
#
# Because first print is use to print NI they are inside the code.
# second print statement is use to print iNeuron because they are outside the code.
#
# 4. What output does this code produce? Why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# global X
# X = 'NI'
#
#
# >>> func()
# >>> print(X)
# Ans:NI
# because we use global statement so it takes NI as a global variable.
#
# 5. What about this code—what’s the output, and why?
#
#
# >>> X = 'iNeuron'
# >>> def func():
# X = 'NI'
# def nested():
# print(X)
# nested()
#
#
# >>> func()
# >>> X
# ANs:iNeuron
# because x is a global variable another x is local so we are calling is return global variable output.
# 6. How about this code: what is its output in Python 3, and explain?
#
#
# >>> def func():
# X = 'NI'
# def nested():
# nonlocal X
# X = 'Spam'
# nested()
# print(X)
#
#
# >>> func()
#
# Ans:it gives syntax error because it cant find binding for nonlocal x
