# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
# 6
#
# ANS:   Values-'hello',6,-87.8
#        Expressions: *,-,/,+
#
# 2. What is the difference between string and variable?
#
# ANS: String is a data type for characters. for example:”my name is rahul”.it includes sequences ,characters ,space ,sentences
# Variables are create to refer the value for others.
# For examples: a=’aman’,here a is a variable.it creates for refer the value for other.
#
# 3. Describe three different data types.
#
# ANS: 1.Integers
# 2.String
# 3.Floating point numbers
#
#
#
# 4.  What is an expression made up of? What do all expressions do?
#
# ANS: Expression is made up of Variables,opertors & Convocations according to the syntax of language.Expressions are giving the value according to elements are given in expressions.
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# ANS: An expression refers to a single value whereas a statement refers to a sentence .
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# ANS.   here bacon =22 so bacon+1=23.
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# ANS: both the value contain “spamspamspam”
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# ANS: because integer can’t be literal.
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# ANS: int()
# str()
# float()
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# ANS: because 99 is an integer .integer with string can’t work
# If   we can write 99 in string form then it is working like this :
#  'I have eaten ' + ‘99’ + ' burritos’
