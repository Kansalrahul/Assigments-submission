# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# ANS:It is very benficial.it can be reuse.it reduces our work.a function can be use again & again.
# it is easy touse ,easy to update.
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# ANS:a function can run when it is called.
#
#
# 3. What statement creates a function?
#
# ANS: def statement creates a function.
#
# 4. What is the difference between a function and a function call?
#
# Ans:A function refers to made a function using def statement.
# A function call means execution of function.
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Ans:There is only one global scope.a local scope is created when function is called.
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Ans:when function call returns,local scope is destroyed & all the variables in it are forgetten.
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Ans:return value is that value a function call evaluates.yes it is possible,it can be used as part of an expression.
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Ans:if function has not return value then its call value is none.
#
#
# 9. How do you make a function variable refer to the global variable?
#
# Ans:A 'global' statement make a function variable refer to the global variable.
#
# 10. What is the data type of None?
#
# Ans: 'nonetype'
#
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Ans:the sentence import the module named areallyourpetsnamederic
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Ans:spam.bacon()
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# ANs:place the line which occurs error in try clause.
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Ans: the line which may occurs an error write in try clause.
#      the code which executes if error happens write in except clause.
